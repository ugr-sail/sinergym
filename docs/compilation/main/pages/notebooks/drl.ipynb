# %% [markdown]
# # DRL usage example

# %% [markdown]
# In this notebook example, Stable Baselines 3 has been used to train and to load an agent. However, Sinergym is completely agnostic to any DRL algorithm (although there are custom callbacks for SB3 specifically) and can be used with any DRL library that works with gymnasium interface.

# %% [markdown]
# ## Training a model

# %% [markdown]
# We are going to rely on the script available in the repository root called `train_agent.py`. This script applies all the possibilities that Sinergym has to work with deep reinforcement learning algorithms and set parameters to everything so that we can define the training options from the execution of the script easily by a JSON file.
#
# For more information about how run `train_agent.py`, please, see [Train a model](https://ugr-sail.github.io/sinergym/compilation/main/pages/deep-reinforcement-learning.html#train-a-model).

# %%
import sys
from datetime import datetime

import gymnasium as gym
import numpy as np
import wandb
from stable_baselines3 import *
from stable_baselines3.common.callbacks import CallbackList
from stable_baselines3.common.logger import HumanOutputFormat
from stable_baselines3.common.logger import Logger as SB3Logger
from stable_baselines3.common.monitor import Monitor

import sinergym
import sinergym.utils.gcloud as gcloud
from sinergym.utils.callbacks import *
from sinergym.utils.constants import *
from sinergym.utils.logger import CSVLogger, WandBOutputFormat
from sinergym.utils.rewards import *
from sinergym.utils.wrappers import *

# %% [markdown]
# First let's define some variables for the execution.

# %%
# Environment ID
environment = "Eplus-5zone-mixed-discrete-stochastic-v1"
# Training episodes
episodes = 5
#Name of the experiment
experiment_date = datetime.today().strftime('%Y-%m-%d_%H:%M')
experiment_name = 'SB3_DQN-' + environment + \
    '-episodes-' + str(episodes)
experiment_name += '_' + experiment_date

# %% [markdown]
# We can combine this experiment executions with [Weights&Biases](https://ugr-sail.github.io/sinergym/compilation/main/pages/deep-reinforcement-learning.html#weights-and-biases-structure) in order to host all information extracted. With *wandb*, it’s possible to track and visualize all DRL training process in real time, register hyperparameters and details of each experiment, save artifacts such as models and *sinergym* output, and compare between different executions.

# %%
# Create wandb.config object in order to log all experiment params
experiment_params = {
    'sinergym-version': sinergym.__version__,
    'python-version': sys.version
}
experiment_params.update({'environment':environment,
                          'episodes':episodes,
                          'algorithm':'SB3_DQN'})

# Get wandb init params (you have to specify your own project and entity)
wandb_params = {"project": 'sinergym',
                "entity": 'alex_ugr'}
# Init wandb entry
run = wandb.init(
    name=experiment_name + '_' + wandb.util.generate_id(),
    config=experiment_params,
    ** wandb_params
)
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: alex_ugr. Use `wandb login --relogin` to force relogin
# wandb version 0.15.10 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.15.5
# Run data is saved locally in <code>/workspaces/sinergym/examples/wandb/run-20230915_154433-rruc1hul</code>
# Syncing run <strong><a href='https://wandb.ai/alex_ugr/sinergym/runs/rruc1hul' target="_blank">SB3_DQN-Eplus-5zone-mixed-discrete-stochastic-v1-episodes-5_2023-09-15_15:44_o37868vr</a></strong> to <a href='https://wandb.ai/alex_ugr/sinergym' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/alex_ugr/sinergym' target="_blank">https://wandb.ai/alex_ugr/sinergym</a>
#  View run at <a href='https://wandb.ai/alex_ugr/sinergym/runs/rruc1hul' target="_blank">https://wandb.ai/alex_ugr/sinergym/runs/rruc1hul</a>

# %% [markdown]
# Now we are ready to create the Gymnasium Environment. Here we use the environment name defined, remember that you can [change default environment configuration](https://ugr-sail.github.io/sinergym/compilation/main/pages/notebooks/change_environment.html#Changing-an-environment-registered-in-Sinergym). We will create a eval_env too in order to interact in the evaluation episodes. We can overwrite the env name with experiment name if we want.

# %%
env = gym.make(environment, env_name=experiment_name)
eval_env = gym.make(environment, env_name=experiment_name+'_EVALUATION')
# Out:
# #==============================================================================================#
# [ENVIRONMENT] (INFO) : Creating Gymnasium environment... [SB3_DQN-Eplus-5zone-mixed-discrete-stochastic-v1-episodes-5_2023-09-15_15:44]
# #==============================================================================================#
# [MODELING] (INFO) : Experiment working directory created [/workspaces/sinergym/examples/Eplus-env-SB3_DQN-Eplus-5zone-mixed-discrete-stochastic-v1-episodes-5_2023-09-15_15:44-res1]
# [MODELING] (INFO) : runperiod established: {'start_day': 1, 'start_month': 1, 'start_year': 1991, 'end_day': 31, 'end_month': 12, 'end_year': 1991, 'start_weekday': 1, 'n_steps_per_hour': 4}
# [MODELING] (INFO) : Episode length (seconds): 31536000.0
# [MODELING] (INFO) : timestep size (seconds): 900.0
# [MODELING] (INFO) : timesteps per episode: 35040
# [MODELING] (INFO) : Model Config is correct.
# [ENVIRONMENT] (INFO) : Environment SB3_DQN-Eplus-5zone-mixed-discrete-stochastic-v1-episodes-5_2023-09-15_15:44 created successfully.
# #==============================================================================================#
# [ENVIRONMENT] (INFO) : Creating Gymnasium environment... [SB3_DQN-Eplus-5zone-mixed-discrete-stochastic-v1-episodes-5_2023-09-15_15:44_EVALUATION]
# #==============================================================================================#
# [MODELING] (INFO) : Experiment working directory created [/workspaces/sinergym/examples/Eplus-env-SB3_DQN-Eplus-5zone-mixed-discrete-stochastic-v1-episodes-5_2023-09-15_15:44_EVALUATION-res1]
# [MODELING] (INFO) : runperiod established: {'start_day': 1, 'start_month': 1, 'start_year': 1991, 'end_day': 31, 'end_month': 12, 'end_year': 1991, 'start_weekday': 1, 'n_steps_per_hour': 4}
# [MODELING] (INFO) : Episode length (seconds): 31536000.0
# [MODELING] (INFO) : timestep size (seconds): 900.0
# [MODELING] (INFO) : timesteps per episode: 35040
# [MODELING] (INFO) : Model Config is correct.
# [ENVIRONMENT] (INFO) : Environment SB3_DQN-Eplus-5zone-mixed-discrete-stochastic-v1-episodes-5_2023-09-15_15:44_EVALUATION created successfully.

# %% [markdown]
# We can also add a Wrapper to the environment, we are going to use a Logger (extension of `gym.Wrapper`) this is used to monitor and log the interactions with the environment and save the data into a CSV. Files generated will be stored as artifact in *wandb* too.

# %%
env = LoggerWrapper(env)
eval_env = LoggerWrapper(eval_env)
# Out:
# [WRAPPER LoggerWrapper] (INFO) : Wrapper initialized.
# [WRAPPER LoggerWrapper] (INFO) : Wrapper initialized.

# %% [markdown]
# At this point, we have the environment set up and ready to be used. We are going to create our learning model (Stable Baselines 3 DQN), but we can use any other algorithm.

# %%
model = DQN('MlpPolicy', env, verbose=1)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %% [markdown]
# Evaluation will execute the current model during a number of episodes determined to decide if it is the best current version of the model at that point of the training. Output generated will be stored in *wandb* server too.
# We are going to use the LoggerEval callback to print and save the best model evaluated during training.

# %%
callbacks = []

# Set up Evaluation and saving best model
eval_callback = LoggerEvalCallback(
    eval_env,
    best_model_save_path=eval_env.get_wrapper_attr('workspace_path') +
    '/best_model/',
    log_path=eval_env.get_wrapper_attr('workspace_path') +
    '/best_model/',
    eval_freq=(eval_env.get_wrapper_attr('timestep_per_episode') - 1) * 2 - 1,
    deterministic=True,
    render=False,
    n_eval_episodes=1)
callbacks.append(eval_callback)

# %% [markdown]
# In order to track all the training process in *wandb*, it is necessary to create a callback with a compatible wandb output format (which call *wandb* log method in the learning algorithm process).

# %%
# wandb logger and setting in SB3
logger = SB3Logger(
    folder=None,
    output_formats=[
        HumanOutputFormat(
            sys.stdout,
            max_length=120),
        WandBOutputFormat()])
model.set_logger(logger)
# Append callback
log_callback = LoggerCallback()
callbacks.append(log_callback)


callback = CallbackList(callbacks)

# %% [markdown]
# This is the number of total time steps for the training.

# %%
timesteps = episodes * (env.get_wrapper_attr('timestep_per_episode') - 1)

# %% [markdown]
# Now, is time to train the model with the callbacks defined earlier. This may take a few minutes, depending on your computer.
#
# :warning: The warning messages that appear in `model.learn()` output is due to Stable Baselines 3 is not adapted to new standar to get environment attributes yet.

# %%
model.learn(
    total_timesteps=timesteps,
    callback=callback,
    log_interval=1)
# Out:
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode... [SB3_DQN-Eplus-5zone-mixed-discrete-stochastic-v1-episodes-5_2023-09-15_15:44] [Episode 1]
# #----------------------------------------------------------------------------------------------#
# [MODELING] (INFO) : Episode directory created [/workspaces/sinergym/examples/Eplus-env-SB3_DQN-Eplus-5zone-mixed-discrete-stochastic-v1-episodes-5_2023-09-15_15:44-res1/Eplus-env-sub_run1]
# [MODELING] (INFO) : Weather file USA_NY_New.York-J.F.Kennedy.Intl.AP.744860_TMY3.epw used.
# [MODELING] (INFO) : Updated building model with whole Output:Variable available names
# [MODELING] (INFO) : Updated building model with whole Output:Meter available names
# [MODELING] (INFO) : Adapting weather to building model. [USA_NY_New.York-J.F.Kennedy.Intl.AP.744860_TMY3.epw]
# [ENVIRONMENT] (INFO) : Saving episode output path... [/workspaces/sinergym/examples/Eplus-env-SB3_DQN-Eplus-5zone-mixed-discrete-stochastic-v1-episodes-5_2023-09-15_15:44-res1/Eplus-env-sub_run1/output]
# /usr/local/lib/python3.10/dist-packages/opyplus/weather_data/weather_data.py:493: FutureWarning: the 'line_terminator'' keyword is deprecated, use 'lineterminator' instead.
#   epw_content = self._headers_to_epw(use_datetimes=use_datetimes) + df.to_csv(
# [SIMULATOR] (INFO) : Running EnergyPlus with args: ['-w', '/workspaces/sinergym/examples/Eplus-env-SB3_DQN-Eplus-5zone-mixed-discrete-stochastic-v1-episodes-5_2023-09-15_15:44-res1/Eplus-env-sub_run1/USA_NY_New.York-J.F.Kennedy.Intl.AP.744860_TMY3_Random_1.0_0.0_0.001.epw', '-d', '/workspaces/sinergym/examples/Eplus-env-SB3_DQN-Eplus-5zone-mixed-discrete-stochastic-v1-episodes-5_2023-09-15_15:44-res1/Eplus-env-sub_run1/output', '/workspaces/sinergym/examples/Eplus-env-SB3_DQN-Eplus-5zone-mixed-discrete-stochastic-v1-episodes-5_2023-09-15_15:44-res1/Eplus-env-sub_run1/5ZoneAutoDXVAV.epJSON']
# [ENVIRONMENT] (INFO) : Episode 1 started.
# [SIMULATOR] (INFO) : handlers initialized.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [WRAPPER LoggerWrapper] (INFO) : Creating monitor.csv for current episode (episode 1) if logger is active
# --------------------------------------------------------------------------------------------------------------| 1%
# | action_network/                 |            |
# |    index                        | 8          |
# | action_simulation/              |            |
# |    Cooling_Setpoint_RL          | 22         |
# |    Heating_Setpoint_RL          | 22         |
# | observation/                    |            |
# |    HVAC_electricity_demand_rate | 3562.1392  |
# |    air_humidity                 | 14.694896  |
# |    air_temperature              | 18.503794  |
# |    clg_setpoint                 | 21.0       |
# |    co2_emission                 | 0.0        |
# |    day_of_month                 | 2.0        |
# |    diffuse_solar_radiation      | 0.0        |
# |    direct_solar_radiation       | 0.0        |
# |    hour                         | 0.0        |
# |    htg_setpoint                 | 21.0       |
# |    month                        | 1.0        |
# |    outdoor_humidity             | 39.0       |
# |    outdoor_temperature          | -11.053787 |
# |    people_occupant              | 0.0        |
# |    total_electricity_HVAC       | 3205925.2  |
# |    wind_direction               | 320.0      |
# |    wind_speed                   | 7.7        |
# | rollout/                        |            |
# |    exploration_rate             | 0.995      |
# ------------------------------------------------
# --------------------------------------------------------------------------------------------------------------| 1%
# | action_network/                 |           |
# |    index                        | 4         |
# | action_simulation/              |           |
# |    Cooling_Setpoint_RL          | 26        |
# |    Heating_Setpoint_RL          | 19        |
# | observation/                    |           |
# |    HVAC_electricity_demand_rate | 2295.943  |
# |    air_humidity                 | 15.371562 |
# |    air_temperature              | 19.25558  |
# |    clg_setpoint                 | 24.0      |
# |    co2_emission                 | 0.0       |
# |    day_of_month                 | 3.0       |
# |    diffuse_solar_radiation      | 0.0       |
# |    direct_solar_radiation       | 0.0       |
# |    hour                         | 1.0       |
# |    htg_setpoint                 | 21.0      |
# |    month                        | 1.0       |
# |    outdoor_humidity             | 62.0      |
# |    outdoor_temperature          | -4.722807 |
# |    people_occupant              | 0.0       |
# |    total_electricity_HVAC       | 2066348.8 |
# |    wind_direction               | 60.0      |
# |    wind_speed                   | 6.2       |
# | rollout/                        |           |
# |    exploration_rate             | 0.989     |
# -----------------------------------------------
# Progress: |*--------------------------------------------------------------------------------------------------| 1%
# /workspaces/sinergym/sinergym/utils/callbacks.py:279: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7fcc85766fe0> != <LoggerWrapper<OrderEnforcing<PassiveEnvChecker<EplusEnv<Eplus-5zone-mixed-discrete-stochastic-v1>>>>>
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/gymnasium/core.py:311: UserWarning: WARN: env.observation_variables to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.observation_variables` for environment variables or `env.get_wrapper_attr('observation_variables')` that will search the reminding wrappers.
#   logger.warn(
# /usr/local/lib/python3.10/dist-packages/gymnasium/core.py:311: UserWarning: WARN: env.action_variables to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.action_variables` for environment variables or `env.get_wrapper_attr('action_variables')` that will search the reminding wrappers.
#   logger.warn(
# /usr/local/lib/python3.10/dist-packages/gymnasium/core.py:311: UserWarning: WARN: env.flag_discrete to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.flag_discrete` for environment variables or `env.get_wrapper_attr('flag_discrete')` that will search the reminding wrappers.
#   logger.warn(
# -------------------------------------------------
# | action_network/                 |             |
# |    index                        | 6           |
# | action_simulation/              |             |
# |    Cooling_Setpoint_RL          | 24          |
# |    Heating_Setpoint_RL          | 21          |
# | observation/                    |             |
# |    HVAC_electricity_demand_rate | 1363.8228   |
# |    air_humidity                 | 41.31368    |
# |    air_temperature              | 18.332386   |
# |    clg_setpoint                 | 27.0        |
# |    co2_emission                 | 0.0         |
# |    day_of_month                 | 4.0         |
# |    diffuse_solar_radiation      | 0.0         |
# |    direct_solar_radiation       | 0.0         |
# |    hour                         | 2.0         |
# |    htg_setpoint                 | 18.0        |
# |    month                        | 1.0         |
# |    outdoor_humidity             | 62.0        |
# |    outdoor_temperature          | -0.06220553 |
# |    people_occupant              | 0.0         |
# |    total_electricity_HVAC       | 1227440.5   |
# |    wind_direction               | 270.0       |
# |    wind_speed                   | 11.3        |
# | rollout/                        |             |
# |    exploration_rate             | 0.984       |
# -------------------------------------------------
# --------------------------------------------------------------------------------------------------------------| 1%
# | action_network/                 |            |
# |    index                        | 8          |
# | action_simulation/              |            |
# |    Cooling_Setpoint_RL          | 22         |
# |    Heating_Setpoint_RL          | 22         |
# | observation/                    |            |
# |    HVAC_electricity_demand_rate | 2798.5093  |
# |    air_humidity                 | 15.661896  |
# |    air_temperature              | 19.664406  |
# |    clg_setpoint                 | 25.0       |
# |    co2_emission                 | 0.0        |
# |    day_of_month                 | 5.0        |
# |    diffuse_solar_radiation      | 0.0        |
# |    direct_solar_radiation       | 0.0        |
# |    hour                         | 3.0        |
# |    htg_setpoint                 | 20.0       |
# |    month                        | 1.0        |
# |    outdoor_humidity             | 50.0       |
# |    outdoor_temperature          | -7.2356377 |
# |    people_occupant              | 0.0        |
# |    total_electricity_HVAC       | 2518658.2  |
# |    wind_direction               | 270.0      |
# |    wind_speed                   | 6.2        |
# | rollout/                        |            |
# |    exploration_rate             | 0.978      |
# ------------------------------------------------
# --------------------------------------------------------------------------------------------------------------| 2%
# | action_network/                 |            |
# |    index                        | 8          |
# | action_simulation/              |            |
# |    Cooling_Setpoint_RL          | 22         |
# |    Heating_Setpoint_RL          | 22         |
# | observation/                    |            |
# |    HVAC_electricity_demand_rate | 3179.0806  |
# |    air_humidity                 | 11.267045  |
# |    air_temperature              | 20.308596  |
# |    clg_setpoint                 | 23.0       |
# |    co2_emission                 | 0.0        |
# |    day_of_month                 | 6.0        |
# |    diffuse_solar_radiation      | 0.0        |
# |    direct_solar_radiation       | 0.0        |
# |    hour                         | 4.0        |
# |    htg_setpoint                 | 22.0       |
# |    month                        | 1.0        |
# |    outdoor_humidity             | 67.0       |
# |    outdoor_temperature          | -9.1384945 |
# |    people_occupant              | 0.0        |
# |    total_electricity_HVAC       | 2861172.5  |
# |    wind_direction               | 240.0      |
# |    wind_speed                   | 3.6        |
# | rollout/                        |            |
# |    exploration_rate             | 0.973      |
# ------------------------------------------------
# --------------------------------------------------------------------------------------------------------------| 2%
# | action_network/                 |            |
# |    index                        | 7          |
# | action_simulation/              |            |
# |    Cooling_Setpoint_RL          | 23         |
# |    Heating_Setpoint_RL          | 22         |
# | observation/                    |            |
# |    HVAC_electricity_demand_rate | 1317.1315  |
# |    air_humidity                 | 14.135364  |
# |    air_temperature              | 17.448359  |
# |    clg_setpoint                 | 28.0       |
# |    co2_emission                 | 0.0        |
# |    day_of_month                 | 7.0        |
# |    diffuse_solar_radiation      | 0.0        |
# |    direct_solar_radiation       | 0.0        |
# |    hour                         | 5.0        |
# |    htg_setpoint                 | 17.0       |
# |    month                        | 1.0        |
# |    outdoor_humidity             | 60.0       |
# |    outdoor_temperature          | 0.17125092 |
# |    people_occupant              | 0.0        |
# |    total_electricity_HVAC       | 1185418.4  |
# |    wind_direction               | 240.0      |
# |    wind_speed                   | 5.7        |
# | rollout/                        |            |
# |    exploration_rate             | 0.968      |
# ------------------------------------------------
# --------------------------------------------------------------------------------------------------------------| 2%
# | action_network/                 |            |
# |    index                        | 4          |
# | action_simulation/              |            |
# |    Cooling_Setpoint_RL          | 26         |
# |    Heating_Setpoint_RL          | 19         |
# | observation/                    |            |
# |    HVAC_electricity_demand_rate | 1554.6903  |
# |    air_humidity                 | 15.709315  |
# |    air_temperature              | 17.500736  |
# |    clg_setpoint                 | 29.0       |
# |    co2_emission                 | 0.0        |
# |    day_of_month                 | 8.0        |
# |    diffuse_solar_radiation      | 0.0        |
# |    direct_solar_radiation       | 0.0        |
# |    hour                         | 6.0        |
# |    htg_setpoint                 | 16.0       |
# |    month                        | 1.0        |
# |    outdoor_humidity             | 41.0       |
# |    outdoor_temperature          | -4.5532975 |
# |    people_occupant              | 0.0        |
# |    total_electricity_HVAC       | 1399221.2  |
# |    wind_direction               | 50.0       |
# |    wind_speed                   | 2.6        |
# | rollout/                        |            |
# |    exploration_rate             | 0.962      |
# ------------------------------------------------
# --------------------------------------------------------------------------------------------------------------| 2%
# | action_network/                 |           |
# |    index                        | 7         |
# | action_simulation/              |           |
# |    Cooling_Setpoint_RL          | 23        |
# |    Heating_Setpoint_RL          | 22        |
# | observation/                    |           |
# |    HVAC_electricity_demand_rate | 427.70825 |
# |    air_humidity                 | 31.053648 |
# |    air_temperature              | 19.99816  |
# |    clg_setpoint                 | 25.0      |
# |    co2_emission                 | 0.0       |
# |    day_of_month                 | 9.0       |
# |    diffuse_solar_radiation      | 39.5      |
# |    direct_solar_radiation       | 9.0       |
# |    hour                         | 7.0       |
# |    htg_setpoint                 | 20.0      |
# |    month                        | 1.0       |
# |    outdoor_humidity             | 100.0     |
# |    outdoor_temperature          | 1.0816126 |
# |    people_occupant              | 0.0       |
# |    total_electricity_HVAC       | 384937.44 |
# |    wind_direction               | 0.0       |
# |    wind_speed                   | 0.0       |
# | rollout/                        |           |
# |    exploration_rate             | 0.957     |
# -----------------------------------------------
# --------------------------------------------------------------------------------------------------------------| 3%
# | action_network/                 |            |
# |    index                        | 4          |
# | action_simulation/              |            |
# |    Cooling_Setpoint_RL          | 26         |
# |    Heating_Setpoint_RL          | 19         |
# | observation/                    |            |
# |    HVAC_electricity_demand_rate | 1747.1637  |
# |    air_humidity                 | 22.459963  |
# |    air_temperature              | 19.986109  |
# |    clg_setpoint                 | 28.0       |
# |    co2_emission                 | 0.0        |
# |    day_of_month                 | 10.0       |
# |    diffuse_solar_radiation      | 124.5      |
# |    direct_solar_radiation       | 318.0      |
# |    hour                         | 8.0        |
# |    htg_setpoint                 | 17.0       |
# |    month                        | 1.0        |
# |    outdoor_humidity             | 72.0       |
# |    outdoor_temperature          | -2.4361348 |
# |    people_occupant              | 11.0       |
# |    total_electricity_HVAC       | 1572447.4  |
# |    wind_direction               | 340.0      |
# |    wind_speed                   | 4.1        |
# | rollout/                        |            |
# |    exploration_rate             | 0.951      |
# ------------------------------------------------
# --------------------------------------------------------------------------------------------------------------| 3%
# | action_network/                 |           |
# |    index                        | 7         |
# | action_simulation/              |           |
# |    Cooling_Setpoint_RL          | 23        |
# |    Heating_Setpoint_RL          | 22        |
# | observation/                    |           |
# |    HVAC_electricity_demand_rate | 2404.8088 |
# |    air_humidity                 | 11.721324 |
# |    air_temperature              | 22.000172 |
# |    clg_setpoint                 | 23.0      |
# |    co2_emission                 | 0.0       |
# |    day_of_month                 | 11.0      |
# |    diffuse_solar_radiation      | 158.0     |
# |    direct_solar_radiation       | 228.0     |
# |    hour                         | 9.0       |
# |    htg_setpoint                 | 22.0      |
# |    month                        | 1.0       |
# |    outdoor_humidity             | 37.0      |
# |    outdoor_temperature          | -5.665231 |
# |    people_occupant              | 11.0      |
# |    total_electricity_HVAC       | 2164328.0 |
# |    wind_direction               | 260.0     |
# |    wind_speed                   | 8.8       |
# | rollout/                        |           |
# |    exploration_rate             | 0.946     |
# -----------------------------------------------
# --------------------------------------------------------------------------------------------------------------| 3%
# | action_network/                 |            |
# |    index                        | 6          |
# | action_simulation/              |            |
# |    Cooling_Setpoint_RL          | 24         |
# |    Heating_Setpoint_RL          | 21         |
# | observation/                    |            |
# |    HVAC_electricity_demand_rate | 101.207115 |
# |    air_humidity                 | 21.638483  |
# |    air_temperature              | 20.142889  |
# |    clg_setpoint                 | 26.0       |
# |    co2_emission                 | 0.0        |
# |    day_of_month                 | 12.0       |
# |    diffuse_solar_radiation      | 202.5      |
# |    direct_solar_radiation       | 79.0       |
# |    hour                         | 10.0       |
# |    htg_setpoint                 | 19.0       |
# |    month                        | 1.0        |
# |    outdoor_humidity             | 61.0       |
# |    outdoor_temperature          | 7.3391714  |
# |    people_occupant              | 0.0        |
# |    total_electricity_HVAC       | 91005.36   |
# |    wind_direction               | 240.0      |
# |    wind_speed                   | 4.6        |
# | rollout/                        |            |
# |    exploration_rate             | 0.94       |
# ------------------------------------------------
# --------------------------------------------------------------------------------------------------------------| 4%
# | action_network/                 |           |
# |    index                        | 0         |
# | action_simulation/              |           |
# |    Cooling_Setpoint_RL          | 30        |
# |    Heating_Setpoint_RL          | 15        |
# | observation/                    |           |
# |    HVAC_electricity_demand_rate | 66.95168  |
# |    air_humidity                 | 29.831232 |
# |    air_temperature              | 19.993181 |
# |    clg_setpoint                 | 25.0      |
# |    co2_emission                 | 0.0       |
# |    day_of_month                 | 13.0      |
# |    diffuse_solar_radiation      | 175.0     |
# |    direct_solar_radiation       | 6.0       |
# |    hour                         | 11.0      |
# |    htg_setpoint                 | 20.0      |
# |    month                        | 1.0       |
# |    outdoor_humidity             | 65.0      |
# |    outdoor_temperature          | 8.242476  |
# |    people_occupant              | 0.0       |
# |    total_electricity_HVAC       | 60256.516 |
# |    wind_direction               | 220.0     |
# |    wind_speed                   | 4.1       |
# | rollout/                        |           |
# |    exploration_rate             | 0.935     |
# -----------------------------------------------
# --------------------------------------------------------------------------------------------------------------| 4%
# | action_network/                 |           |
# |    index                        | 7         |
# | action_simulation/              |           |
# |    Cooling_Setpoint_RL          | 23        |
# |    Heating_Setpoint_RL          | 22        |
# | observation/                    |           |
# |    HVAC_electricity_demand_rate | 2317.2751 |
# |    air_humidity                 | 18.059267 |
# |    air_temperature              | 19.848759 |
# |    clg_setpoint                 | 26.0      |
# |    co2_emission                 | 0.0       |
# |    day_of_month                 | 14.0      |
# |    diffuse_solar_radiation      | 76.0      |
# |    direct_solar_radiation       | 0.0       |
# |    hour                         | 12.0      |
# |    htg_setpoint                 | 19.0      |
# |    month                        | 1.0       |
# |    outdoor_humidity             | 83.0      |
# |    outdoor_temperature          | -7.205855 |
# |    people_occupant              | 4.4       |
# |    total_electricity_HVAC       | 2085547.8 |
# |    wind_direction               | 50.0      |
# |    wind_speed                   | 9.8       |
# | rollout/                        |           |
# |    exploration_rate             | 0.93      |
# -----------------------------------------------
# --------------------------------------------------------------------------------------------------------------| 4%
# | action_network/                 |           |
# |    index                        | 1         |
# | action_simulation/              |           |
# |    Cooling_Setpoint_RL          | 29        |
# |    Heating_Setpoint_RL          | 16        |
# | observation/                    |           |
# |    HVAC_electricity_demand_rate | 755.6465  |
# |    air_humidity                 | 36.855843 |
# |    air_temperature              | 21.722557 |
# |    clg_setpoint                 | 27.0      |
# |    co2_emission                 | 0.0       |
# |    day_of_month                 | 15.0      |
# |    diffuse_solar_radiation      | 140.5     |
# |    direct_solar_radiation       | 12.0      |
# |    hour                         | 13.0      |
# |    htg_setpoint                 | 18.0      |
# |    month                        | 1.0       |
# |    outdoor_humidity             | 100.0     |
# |    outdoor_temperature          | 2.0682583 |
# |    people_occupant              | 8.8       |
# |    total_electricity_HVAC       | 680081.9  |
# |    wind_direction               | 250.0     |
# |    wind_speed                   | 5.7       |
# | rollout/                        |           |
# |    exploration_rate             | 0.924     |
# -----------------------------------------------
# --------------------------------------------------------------------------------------------------------------| 4%
# | action_network/                 |           |
# |    index                        | 2         |
# | action_simulation/              |           |
# |    Cooling_Setpoint_RL          | 28        |
# |    Heating_Setpoint_RL          | 17        |
# | observation/                    |           |
# |    HVAC_electricity_demand_rate | 951.3817  |
# |    air_humidity                 | 19.886553 |
# |    air_temperature              | 28.906307 |
# |    clg_setpoint                 | 22.0      |
# |    co2_emission                 | 0.0       |
# |    day_of_month                 | 16.0      |
# |    diffuse_solar_radiation      | 71.5      |
# |    direct_solar_radiation       | 590.5     |
# |    hour                         | 14.0      |
# |    htg_setpoint                 | 22.0      |
# |    month                        | 1.0       |
# |    outdoor_humidity             | 70.0      |
# |    outdoor_temperature          | 4.9379473 |
# |    people_occupant              | 11.0      |
# |    total_electricity_HVAC       | 856243.5  |
# |    wind_direction               | 210.0     |
# |    wind_speed                   | 4.1       |
# | rollout/                        |           |
# |    exploration_rate             | 0.919     |
# -----------------------------------------------
# --------------------------------------------------------------------------------------------------------------| 5%
# | action_network/                 |           |
# |    index                        | 3         |
# | action_simulation/              |           |
# |    Cooling_Setpoint_RL          | 27        |
# |    Heating_Setpoint_RL          | 18        |
# | observation/                    |           |
# |    HVAC_electricity_demand_rate | 590.56445 |
# |    air_humidity                 | 18.972523 |
# |    air_temperature              | 29.993166 |
# |    clg_setpoint                 | 27.0      |
# |    co2_emission                 | 0.0       |
# |    day_of_month                 | 17.0      |
# |    diffuse_solar_radiation      | 33.0      |
# |    direct_solar_radiation       | 392.0     |
# |    hour                         | 15.0      |
# |    htg_setpoint                 | 18.0      |
# |    month                        | 1.0       |
# |    outdoor_humidity             | 43.0      |
# |    outdoor_temperature          | 9.963505  |
# |    people_occupant              | 11.0      |
# |    total_electricity_HVAC       | 532175.3  |
# |    wind_direction               | 220.0     |
# |    wind_speed                   | 2.1       |
# | rollout/                        |           |
# |    exploration_rate             | 0.913     |
# -----------------------------------------------
# --------------------------------------------------------------------------------------------------------------| 5%
# | action_network/                 |           |
# |    index                        | 8         |
# | action_simulation/              |           |
# |    Cooling_Setpoint_RL          | 22        |
# |    Heating_Setpoint_RL          | 22        |
# | observation/                    |           |
# |    HVAC_electricity_demand_rate | 519.2349  |
# |    air_humidity                 | 58.444565 |
# |    air_temperature              | 22.127396 |
# |    clg_setpoint                 | 26.0      |
# |    co2_emission                 | 0.0       |
# |    day_of_month                 | 18.0      |
# |    diffuse_solar_radiation      | 0.0       |
# |    direct_solar_radiation       | 0.0       |
# |    hour                         | 16.0      |
# |    htg_setpoint                 | 19.0      |
# |    month                        | 1.0       |
# |    outdoor_humidity             | 96.0      |
# |    outdoor_temperature          | 11.931481 |
# |    people_occupant              | 11.0      |
# |    total_electricity_HVAC       | 467311.4  |
# |    wind_direction               | 160.0     |
# |    wind_speed                   | 11.8      |
# | rollout/                        |           |
# |    exploration_rate             | 0.908     |
# -----------------------------------------------
# --------------------------------------------------------------------------------------------------------------| 5%
# | action_network/                 |           |
# |    index                        | 7         |
# | action_simulation/              |           |
# |    Cooling_Setpoint_RL          | 23        |
# |    Heating_Setpoint_RL          | 22        |
# | observation/                    |           |
# |    HVAC_electricity_demand_rate | 66.95168  |
# |    air_humidity                 | 19.508364 |
# |    air_temperature              | 22.000004 |
# |    clg_setpoint                 | 23.0      |
# |    co2_emission                 | 0.0       |
# |    day_of_month                 | 19.0      |
# |    diffuse_solar_radiation      | 0.0       |
# |    direct_solar_radiation       | 0.0       |
# |    hour                         | 17.0      |
# |    htg_setpoint                 | 22.0      |
# |    month                        | 1.0       |
# |    outdoor_humidity             | 39.0      |
# |    outdoor_temperature          | 7.3573914 |
# |    people_occupant              | 0.0       |
# |    total_electricity_HVAC       | 60256.516 |
# |    wind_direction               | 250.0     |
# |    wind_speed                   | 6.7       |
# | rollout/                        |           |
# |    exploration_rate             | 0.903     |
# -----------------------------------------------
# --------------------------------------------------------------------------------------------------------------| 5%
# | action_network/                 |           |
# |    index                        | 0         |
# | action_simulation/              |           |
# |    Cooling_Setpoint_RL          | 30        |
# |    Heating_Setpoint_RL          | 15        |
# | observation/                    |           |
# |    HVAC_electricity_demand_rate | 66.95168  |
# |    air_humidity                 | 25.715015 |
# |    air_temperature              | 19.412962 |
# |    clg_setpoint                 | 29.0      |
# |    co2_emission                 | 0.0       |
# |    day_of_month                 | 20.0      |
# |    diffuse_solar_radiation      | 0.0       |
# |    direct_solar_radiation       | 0.0       |
# |    hour                         | 18.0      |
# |    htg_setpoint                 | 16.0      |
# |    month                        | 1.0       |
# |    outdoor_humidity             | 82.0      |
# |    outdoor_temperature          | 4.8151565 |
# |    people_occupant              | 0.0       |
# |    total_electricity_HVAC       | 60256.516 |
# |    wind_direction               | 200.0     |
# |    wind_speed                   | 3.1       |
# | rollout/                        |           |
# |    exploration_rate             | 0.897     |
# -----------------------------------------------
# --------------------------------------------------------------------------------------------------------------| 6%
# | action_network/                 |           |
# |    index                        | 6         |
# | action_simulation/              |           |
# |    Cooling_Setpoint_RL          | 24        |
# |    Heating_Setpoint_RL          | 21        |
# | observation/                    |           |
# |    HVAC_electricity_demand_rate | 351.4602  |
# |    air_humidity                 | 44.3629   |
# |    air_temperature              | 22.000256 |
# |    clg_setpoint                 | 22.0      |
# |    co2_emission                 | 0.0       |
# |    day_of_month                 | 21.0      |
# |    diffuse_solar_radiation      | 0.0       |
# |    direct_solar_radiation       | 0.0       |
# |    hour                         | 19.0      |
# |    htg_setpoint                 | 22.0      |
# |    month                        | 1.0       |
# |    outdoor_humidity             | 90.0      |
# |    outdoor_temperature          | 8.927895  |
# |    people_occupant              | 1.1       |
# |    total_electricity_HVAC       | 324374.1  |
# |    wind_direction               | 40.0      |
# |    wind_speed                   | 5.2       |
# | rollout/                        |           |
# |    exploration_rate             | 0.892     |
# -----------------------------------------------
# --------------------------------------------------------------------------------------------------------------| 6%
# | action_network/                 |           |
# |    index                        | 2         |
# | action_simulation/              |           |
# |    Cooling_Setpoint_RL          | 28        |
# |    Heating_Setpoint_RL          | 17        |
# | observation/                    |           |
# |    HVAC_electricity_demand_rate | 761.80225 |
# |    air_humidity                 | 42.69713  |
# |    air_temperature              | 19.433533 |
# |    clg_setpoint                 | 30.0      |
# |    co2_emission                 | 0.0       |
# |    day_of_month                 | 22.0      |
# |    diffuse_solar_radiation      | 0.0       |
# |    direct_solar_radiation       | 0.0       |
# |    hour                         | 20.0      |
# |    htg_setpoint                 | 15.0      |
# |    month                        | 1.0       |
# |    outdoor_humidity             | 97.0      |
# |    outdoor_temperature          | 5.752059  |
# |    people_occupant              | 1.1       |
# |    total_electricity_HVAC       | 667378.06 |
# |    wind_direction               | 60.0      |
# |    wind_speed                   | 6.2       |
# | rollout/                        |           |
# |    exploration_rate             | 0.886     |
# -----------------------------------------------
# --------------------------------------------------------------------------------------------------------------| 6%
# | action_network/                 |           |
# |    index                        | 9         |
# | action_simulation/              |           |
# |    Cooling_Setpoint_RL          | 21        |
# |    Heating_Setpoint_RL          | 21        |
# | observation/                    |           |
# |    HVAC_electricity_demand_rate | 353.41003 |
# |    air_humidity                 | 50.286156 |
# |    air_temperature              | 21.00012  |
# |    clg_setpoint                 | 24.0      |
# |    co2_emission                 | 0.0       |
# |    day_of_month                 | 23.0      |
# |    diffuse_solar_radiation      | 0.0       |
# |    direct_solar_radiation       | 0.0       |
# |    hour                         | 21.0      |
# |    htg_setpoint                 | 21.0      |
# |    month                        | 1.0       |
# |    outdoor_humidity             | 96.0      |
# |    outdoor_temperature          | 9.91965   |
# |    people_occupant              | 0.0       |
# |    total_electricity_HVAC       | 316857.44 |
# |    wind_direction               | 150.0     |
# |    wind_speed                   | 5.7       |
# | rollout/                        |           |
# |    exploration_rate             | 0.881     |
# -----------------------------------------------
# --------------------------------------------------------------------------------------------------------------| 7%
# | action_network/                 |           |
# |    index                        | 0         |
# | action_simulation/              |           |
# |    Cooling_Setpoint_RL          | 30        |
# |    Heating_Setpoint_RL          | 15        |
# | observation/                    |           |
# |    HVAC_electricity_demand_rate | 597.5618  |
# |    air_humidity                 | 36.21696  |
# |    air_temperature              | 21.000864 |
# |    clg_setpoint                 | 21.0      |
# |    co2_emission                 | 0.0       |
# |    day_of_month                 | 24.0      |
# |    diffuse_solar_radiation      | 0.0       |
# |    direct_solar_radiation       | 0.0       |
# |    hour                         | 22.0      |
# |    htg_setpoint                 | 21.0      |
# |    month                        | 1.0       |
# |    outdoor_humidity             | 62.0      |
# |    outdoor_temperature          | 6.73791   |
# |    people_occupant              | 0.0       |
# |    total_electricity_HVAC       | 537805.6  |
# |    wind_direction               | 310.0     |
# |    wind_speed                   | 9.3       |
# | rollout/                        |           |
# |    exploration_rate             | 0.875     |
# -----------------------------------------------
# Progress: |*******--------------------------------------------------------------------------------------------| 7%-----------------------------------------------
# | action_network/                 |           |
# |    index                        | 2         |
# | action_simulation/              |           |
# |    Cooling_Setpoint_RL          | 28        |
# |    Heating_Setpoint_RL          | 17        |
# | observation/                    |           |
# |    HVAC_electricity_demand_rate | 951.3817  |
# |    air_humidity                 | 34.866764 |
# |    air_temperature              | 21.27741  |
# |    clg_setpoint                 | 23.0      |
# |    co2_emission                 | 0.0       |
# |    day_of_month                 | 25.0      |
# |    diffuse_solar_radiation      | 0.0       |
# |    direct_solar_radiation       | 0.0       |
# |    hour                         | 23.0      |
# |    htg_setpoint                 | 22.0      |
# |    month                        | 1.0       |
# |    outdoor_humidity             | 64.0      |
# |    outdoor_temperature          | 2.2034512 |
# |    people_occupant              | 0.0       |
# |    total_electricity_HVAC       | 856243.5  |
# |    wind_direction               | 310.0     |
# |    wind_speed                   | 7.2       |
# | rollout/                        |           |
# |    exploration_rate             | 0.87      |
# -----------------------------------------------
# --------------------------------------------------------------------------------------------------------------| 7%
# | action_network/                 |           |
# |    index                        | 5         |
# | action_simulation/              |           |
# |    Cooling_Setpoint_RL          | 25        |
# |    Heating_Setpoint_RL          | 20        |
# | observation/                    |           |
# |    HVAC_electricity_demand_rate | 985.88464 |
# |    air_humidity                 | 24.533226 |
# |    air_temperature              | 20.916525 |
# |    clg_setpoint                 | 23.0      |
# |    co2_emission                 | 0.0       |
# |    day_of_month                 | 27.0      |
# |    diffuse_solar_radiation      | 0.0       |
# |    direct_solar_radiation       | 0.0       |
# |    hour                         | 0.0       |
# |    htg_setpoint                 | 22.0      |
# |    month                        | 1.0       |
# |    outdoor_humidity             | 88.0      |
# |    outdoor_temperature          | 1.8274853 |
# |    people_occupant              | 0.0       |
# |    total_electricity_HVAC       | 887296.2  |
# |    wind_direction               | 250.0     |
# |    wind_speed                   | 3.6       |
# | rollout/                        |           |
# |    exploration_rate             | 0.865     |
# -----------------------------------------------
# --------------------------------------------------------------------------------------------------------------| 8%
# | action_network/                 |           |
# |    index                        | 2         |
# | action_simulation/              |           |
# |    Cooling_Setpoint_RL          | 28        |
# |    Heating_Setpoint_RL          | 17        |
# | observation/                    |           |
# |    HVAC_electricity_demand_rate | 951.3817  |
# |    air_humidity                 | 26.281553 |
# |    air_temperature              | 20.004633 |
# |    clg_setpoint                 | 25.0      |
# |    co2_emission                 | 0.0       |
# |    day_of_month                 | 28.0      |
# |    diffuse_solar_radiation      | 0.0       |
# |    direct_solar_radiation       | 0.0       |
# |    hour                         | 1.0       |
# |    htg_setpoint                 | 20.0      |
# |    month                        | 1.0       |
# |    outdoor_humidity             | 92.0      |
# |    outdoor_temperature          | 3.1812935 |
# |    people_occupant              | 0.0       |
# |    total_electricity_HVAC       | 856243.5  |
# |    wind_direction               | 30.0      |
# |    wind_speed                   | 2.6       |
# | rollout/                        |           |
# |    exploration_rate             | 0.859     |
# -----------------------------------------------
# --------------------------------------------------------------------------------------------------------------| 8%
# | action_network/                 |           |
# |    index                        | 6         |
# | action_simulation/              |           |
# |    Cooling_Setpoint_RL          | 24        |
# |    Heating_Setpoint_RL          | 21        |
# | observation/                    |           |
# |    HVAC_electricity_demand_rate | 1049.4585 |
# |    air_humidity                 | 37.366756 |
# |    air_temperature              | 20.99963  |
# |    clg_setpoint                 | 24.0      |
# |    co2_emission                 | 0.0       |
# |    day_of_month                 | 29.0      |
# |    diffuse_solar_radiation      | 0.0       |
# |    direct_solar_radiation       | 0.0       |
# |    hour                         | 2.0       |
# |    htg_setpoint                 | 21.0      |
# |    month                        | 1.0       |
# |    outdoor_humidity             | 96.0      |
# |    outdoor_temperature          | 1.5096161 |
# |    people_occupant              | 0.0       |
# |    total_electricity_HVAC       | 944512.6  |
# |    wind_direction               | 340.0     |
# |    wind_speed                   | 2.1       |
# | rollout/                        |           |
# |    exploration_rate             | 0.854     |
# -----------------------------------------------
# --------------------------------------------------------------------------------------------------------------| 8%
# | action_network/                 |            |
# |    index                        | 9          |
# | action_simulation/              |            |
# |    Cooling_Setpoint_RL          | 21         |
# |    Heating_Setpoint_RL          | 21         |
# | observation/                    |            |
# |    HVAC_electricity_demand_rate | 1949.834   |
# |    air_humidity                 | 26.284477  |
# |    air_temperature              | 20.27916   |
# |    clg_setpoint                 | 22.0       |
# |    co2_emission                 | 0.0        |
# |    day_of_month                 | 30.0       |
# |    diffuse_solar_radiation      | 0.0        |
# |    direct_solar_radiation       | 0.0        |
# |    hour                         | 3.0        |
# |    htg_setpoint                 | 22.0       |
# |    month                        | 1.0        |
# |    outdoor_humidity             | 65.0       |
# |    outdoor_temperature          | -2.9922612 |
# |    people_occupant              | 0.0        |
# |    total_electricity_HVAC       | 1754850.5  |
# |    wind_direction               | 340.0      |
# |    wind_speed                   | 2.1        |
# | rollout/                        |            |
# |    exploration_rate             | 0.848      |
# ------------------------------------------------
# --------------------------------------------------------------------------------------------------------------| 8%
# | action_network/                 |           |
# |    index                        | 5         |
# | action_simulation/              |           |
# |    Cooling_Setpoint_RL          | 25        |
# |    Heating_Setpoint_RL          | 20        |
# | observation/                    |           |
# |    HVAC_electricity_demand_rate | 3246.3525 |
# |    air_humidity                 | 22.475962 |
# |    air_temperature              | 19.418036 |
# |    clg_setpoint                 | 23.0      |
# |    co2_emission                 | 0.0       |
# |    day_of_month                 | 31.0      |
# |    diffuse_solar_radiation      | 0.0       |
# |    direct_solar_radiation       | 0.0       |
# |    hour                         | 4.0       |
# |    htg_setpoint                 | 22.0      |
# |    month                        | 1.0       |
# |    outdoor_humidity             | 33.0      |
# |    outdoor_temperature          | -9.474854 |
# |    people_occupant              | 0.0       |
# |    total_electricity_HVAC       | 2921717.2 |
# |    wind_direction               | 20.0      |
# |    wind_speed                   | 7.2       |
# | rollout/                        |           |
# |    exploration_rate             | 0.843     |
# -----------------------------------------------
# --------------------------------------------------------------------------------------------------------------| 9%
# | action_network/                 |           |
# |    index                        | 3         |
# | action_simulation/              |           |
# |    Cooling_Setpoint_RL          | 27        |
# |    Heating_Setpoint_RL          | 18        |
# | observation/                    |           |
# |    HVAC_electricity_demand_rate | 951.3817  |
# |    air_humidity                 | 18.336016 |
# |    air_temperature              | 19.814533 |
# |    clg_setpoint                 | 25.0      |
# |    co2_emission                 | 0.0       |
# |    day_of_month                 | 1.0       |
# |    diffuse_solar_radiation      | 0.0       |
# |    direct_solar_radiation       | 0.0       |
# |    hour                         | 5.0       |
# |    htg_setpoint                 | 20.0      |
# |    month                        | 2.0       |
# |    outdoor_humidity             | 70.0      |
# |    outdoor_temperature          | 1.1025134 |
# |    people_occupant              | 0.0       |
# |    total_electricity_HVAC       | 856243.5  |
# |    wind_direction               | 250.0     |
# |    wind_speed                   | 5.2       |
# | rollout/                        |           |
# |    exploration_rate             | 0.837     |
# -----------------------------------------------
# --------------------------------------------------------------------------------------------------------------| 9%
# | action_network/                 |           |
# |    index                        | 2         |
# | action_simulation/              |           |
# |    Cooling_Setpoint_RL          | 28        |
# |    Heating_Setpoint_RL          | 17        |
# | observation/                    |           |
# |    HVAC_electricity_demand_rate | 258.5179  |
# |    air_humidity                 | 29.730331 |
# |    air_temperature              | 17.773428 |
# |    clg_setpoint                 | 28.0      |
# |    co2_emission                 | 0.0       |
# |    day_of_month                 | 2.0       |
# |    diffuse_solar_radiation      | 0.0       |
# |    direct_solar_radiation       | 0.0       |
# |    hour                         | 6.0       |
# |    htg_setpoint                 | 17.0      |
# |    month                        | 2.0       |
# |    outdoor_humidity             | 45.0      |
# |    outdoor_temperature          | 5.227357  |
# |    people_occupant              | 0.0       |
# |    total_electricity_HVAC       | 232666.11 |
# |    wind_direction               | 320.0     |
# |    wind_speed                   | 6.7       |
# | rollout/                        |           |
# |    exploration_rate             | 0.832     |
# -----------------------------------------------
# --------------------------------------------------------------------------------------------------------------| 9%
# | action_network/                 |            |
# |    index                        | 0          |
# | action_simulation/              |            |
# |    Cooling_Setpoint_RL          | 30         |
# |    Heating_Setpoint_RL          | 15         |
# | observation/                    |            |
# |    HVAC_electricity_demand_rate | 2874.4646  |
# |    air_humidity                 | 11.638157  |
# |    air_temperature              | 20.851654  |
# |    clg_setpoint                 | 21.0       |
# |    co2_emission                 | 0.0        |
# |    day_of_month                 | 3.0        |
# |    diffuse_solar_radiation      | 32.0       |
# |    direct_solar_radiation       | 410.0      |
# |    hour                         | 7.0        |
# |    htg_setpoint                 | 21.0       |
# |    month                        | 2.0        |
# |    outdoor_humidity             | 53.0       |
# |    outdoor_temperature          | -7.6154146 |
# |    people_occupant              | 0.0        |
# |    total_electricity_HVAC       | 2587018.2  |
# |    wind_direction               | 20.0       |
# |    wind_speed                   | 4.6        |
# | rollout/                        |            |
# |    exploration_rate             | 0.827      |
# ------------------------------------------------
# --------------------------------------------------------------------------------------------------------------| 10%
# | action_network/                 |            |
# |    index                        | 6          |
# | action_simulation/              |            |
# |    Cooling_Setpoint_RL          | 24         |
# ...
# |    people_occupant              | 1.1       |
# |    total_electricity_HVAC       | 445863.4  |
# |    wind_direction               | 260.0     |
# |    wind_speed                   | 4.75      |
# | rollout/                        |           |
# |    exploration_rate             | 0.05      |
# | train/                          |           |
# |    learning_rate                | 0.0001    |
# |    loss                         | 4.46e+03  |
# |    n_updates                    | 31149     |
# -----------------------------------------------
# -----------------------------------------------**************************************************************-| 98%
# | action_network/                 |           |
# |    index                        | 5         |
# | action_simulation/              |           |
# |    Cooling_Setpoint_RL          | 25        |
# |    Heating_Setpoint_RL          | 20        |
# | observation/                    |           |
# |    HVAC_electricity_demand_rate | 474.4713  |
# |    air_humidity                 | 31.969433 |
# |    air_temperature              | 19.19034  |
# |    clg_setpoint                 | 27.0      |
# |    co2_emission                 | 0.0       |
# |    day_of_month                 | 26.0      |
# |    diffuse_solar_radiation      | 0.0       |
# |    direct_solar_radiation       | 0.0       |
# |    hour                         | 20.0      |
# |    htg_setpoint                 | 18.0      |
# |    month                        | 12.0      |
# |    outdoor_humidity             | 52.0      |
# |    outdoor_temperature          | 8.035118  |
# |    people_occupant              | 1.1       |
# |    total_electricity_HVAC       | 417943.97 |
# |    wind_direction               | 262.5     |
# |    wind_speed                   | 7.45      |
# | rollout/                        |           |
# |    exploration_rate             | 0.05      |
# | train/                          |           |
# |    learning_rate                | 0.0001    |
# |    loss                         | 1.49e+03  |
# |    n_updates                    | 31174     |
# -----------------------------------------------
# -----------------------------------------------**************************************************************-| 98%
# | action_network/                 |           |
# |    index                        | 7         |
# | action_simulation/              |           |
# |    Cooling_Setpoint_RL          | 23        |
# |    Heating_Setpoint_RL          | 22        |
# | observation/                    |           |
# |    HVAC_electricity_demand_rate | 1188.9001 |
# |    air_humidity                 | 35.63206  |
# |    air_temperature              | 21.999802 |
# |    clg_setpoint                 | 23.0      |
# |    co2_emission                 | 0.0       |
# |    day_of_month                 | 27.0      |
# |    diffuse_solar_radiation      | 0.0       |
# |    direct_solar_radiation       | 0.0       |
# |    hour                         | 21.0      |
# |    htg_setpoint                 | 22.0      |
# |    month                        | 12.0      |
# |    outdoor_humidity             | 96.0      |
# |    outdoor_temperature          | 0.8124077 |
# |    people_occupant              | 0.0       |
# |    total_electricity_HVAC       | 1070010.1 |
# |    wind_direction               | 7.5       |
# |    wind_speed                   | 7.225     |
# | rollout/                        |           |
# |    exploration_rate             | 0.05      |
# | train/                          |           |
# |    learning_rate                | 0.0001    |
# |    loss                         | 2.91e+03  |
# |    n_updates                    | 31199     |
# -----------------------------------------------
# ------------------------------------------------**************************************************************| 99%
# | action_network/                 |            |
# |    index                        | 8          |
# | action_simulation/              |            |
# |    Cooling_Setpoint_RL          | 22         |
# |    Heating_Setpoint_RL          | 22         |
# | observation/                    |            |
# |    HVAC_electricity_demand_rate | 1287.3749  |
# |    air_humidity                 | 19.57846   |
# |    air_temperature              | 22.000006  |
# |    clg_setpoint                 | 22.0       |
# |    co2_emission                 | 0.0        |
# |    day_of_month                 | 28.0       |
# |    diffuse_solar_radiation      | 0.0        |
# |    direct_solar_radiation       | 0.0        |
# |    hour                         | 22.0       |
# |    htg_setpoint                 | 22.0       |
# |    month                        | 12.0       |
# |    outdoor_humidity             | 54.5       |
# |    outdoor_temperature          | 0.32003403 |
# |    people_occupant              | 0.0        |
# |    total_electricity_HVAC       | 1158637.4  |
# |    wind_direction               | 40.0       |
# |    wind_speed                   | 2.225      |
# | rollout/                        |            |
# |    exploration_rate             | 0.05       |
# | train/                          |            |
# |    learning_rate                | 0.0001     |
# |    loss                         | 3.44e+03   |
# |    n_updates                    | 31224      |
# ------------------------------------------------
# -----------------------------------------------***************************************************************| 99%
# | action_network/                 |           |
# |    index                        | 6         |
# | action_simulation/              |           |
# |    Cooling_Setpoint_RL          | 24        |
# |    Heating_Setpoint_RL          | 21        |
# | observation/                    |           |
# |    HVAC_electricity_demand_rate | 108.61107 |
# |    air_humidity                 | 33.78892  |
# |    air_temperature              | 20.999966 |
# |    clg_setpoint                 | 24.0      |
# |    co2_emission                 | 0.0       |
# |    day_of_month                 | 29.0      |
# |    diffuse_solar_radiation      | 0.0       |
# |    direct_solar_radiation       | 0.0       |
# |    hour                         | 23.0      |
# |    htg_setpoint                 | 21.0      |
# |    month                        | 12.0      |
# |    outdoor_humidity             | 96.75     |
# |    outdoor_temperature          | 5.498481  |
# |    people_occupant              | 0.0       |
# |    total_electricity_HVAC       | 97749.96  |
# |    wind_direction               | 27.5      |
# |    wind_speed                   | 12.475    |
# | rollout/                        |           |
# |    exploration_rate             | 0.05      |
# | train/                          |           |
# |    learning_rate                | 0.0001    |
# |    loss                         | 1.09e+03  |
# |    n_updates                    | 31249     |
# -----------------------------------------------
# ----------------------------------------------****************************************************************| 99%
# | action_network/                 |          |
# |    index                        | 0        |
# | action_simulation/              |          |
# |    Cooling_Setpoint_RL          | 30       |
# |    Heating_Setpoint_RL          | 15       |
# | observation/                    |          |
# |    HVAC_electricity_demand_rate | 951.3817 |
# |    air_humidity                 | 36.21885 |
# |    air_temperature              | 16.65966 |
# |    clg_setpoint                 | 30.0     |
# |    co2_emission                 | 0.0      |
# |    day_of_month                 | 31.0     |
# |    diffuse_solar_radiation      | 0.0      |
# |    direct_solar_radiation       | 0.0      |
# |    hour                         | 0.0      |
# |    htg_setpoint                 | 15.0     |
# |    month                        | 12.0     |
# |    outdoor_humidity             | 56.0     |
# |    outdoor_temperature          | 2.627797 |
# |    people_occupant              | 0.0      |
# |    total_electricity_HVAC       | 856243.5 |
# |    wind_direction               | 252.5    |
# |    wind_speed                   | 11.05    |
# | rollout/                        |          |
# |    exploration_rate             | 0.05     |
# | train/                          |          |
# |    learning_rate                | 0.0001   |
# |    loss                         | 1.1e+03  |
# |    n_updates                    | 31274    |
# ----------------------------------------------
#
# [WRAPPER LoggerWrapper] (INFO) : End of episode detected, recording summary (progress.csv) if logger is active
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode... [SB3_DQN-Eplus-5zone-mixed-discrete-stochastic-v1-episodes-5_2023-09-15_15:44] [Episode 6]
# #----------------------------------------------------------------------------------------------#
# [MODELING] (INFO) : Episode directory created [/workspaces/sinergym/examples/Eplus-env-SB3_DQN-Eplus-5zone-mixed-discrete-stochastic-v1-episodes-5_2023-09-15_15:44-res1/Eplus-env-sub_run6]
# [MODELING] (INFO) : Weather file USA_NY_New.York-J.F.Kennedy.Intl.AP.744860_TMY3.epw used.
# [MODELING] (INFO) : Updated building model with whole Output:Variable available names
# [MODELING] (INFO) : Updated building model with whole Output:Meter available names
# [MODELING] (INFO) : Adapting weather to building model. [USA_NY_New.York-J.F.Kennedy.Intl.AP.744860_TMY3.epw]
# [ENVIRONMENT] (INFO) : Saving episode output path... [/workspaces/sinergym/examples/Eplus-env-SB3_DQN-Eplus-5zone-mixed-discrete-stochastic-v1-episodes-5_2023-09-15_15:44-res1/Eplus-env-sub_run6/output]
# [SIMULATOR] (INFO) : Running EnergyPlus with args: ['-w', '/workspaces/sinergym/examples/Eplus-env-SB3_DQN-Eplus-5zone-mixed-discrete-stochastic-v1-episodes-5_2023-09-15_15:44-res1/Eplus-env-sub_run6/USA_NY_New.York-J.F.Kennedy.Intl.AP.744860_TMY3_Random_1.0_0.0_0.001.epw', '-d', '/workspaces/sinergym/examples/Eplus-env-SB3_DQN-Eplus-5zone-mixed-discrete-stochastic-v1-episodes-5_2023-09-15_15:44-res1/Eplus-env-sub_run6/output', '/workspaces/sinergym/examples/Eplus-env-SB3_DQN-Eplus-5zone-mixed-discrete-stochastic-v1-episodes-5_2023-09-15_15:44-res1/Eplus-env-sub_run6/5ZoneAutoDXVAV.epJSON']
# [ENVIRONMENT] (INFO) : Episode 6 started.
# /usr/local/lib/python3.10/dist-packages/opyplus/weather_data/weather_data.py:493: FutureWarning: the 'line_terminator'' keyword is deprecated, use 'lineterminator' instead.
#   epw_content = self._headers_to_epw(use_datetimes=use_datetimes) + df.to_csv(
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [WRAPPER LoggerWrapper] (INFO) : Creating monitor.csv for current episode (episode 6) if logger is active
# -----------------------------------------------------
# | action_network/                     |             |
# |    index                            | 9           |
# | action_simulation/                  |             |
# |    Cooling_Setpoint_RL              | 21          |
# |    Heating_Setpoint_RL              | 21          |
# | episode/                            |             |
# |    comfort_violation_time(%)        | 53.1        |
# |    cumulative_comfort_penalty       | -3.73e+04   |
# |    cumulative_energy_penalty        | -3.56e+03   |
# |    cumulative_power                 | 7.11e+07    |
# |    cumulative_reward                | -40892.617  |
# |    cumulative_temperature_violation | 7.47e+04    |
# |    episode_length                   | 70077       |
# |    mean_comfort_penalty             | -0.533      |
# |    mean_energy_penalty              | -0.0508     |
# |    mean_power                       | 1.02e+03    |
# |    mean_reward                      | -0.58353835 |
# |    mean_temperature_violation       | 1.07        |
# | observation/                        |             |
# |    HVAC_electricity_demand_rate     | 3242.7075   |
# |    air_humidity                     | 19.767397   |
# |    air_temperature                  | 14.529034   |
# |    clg_setpoint                     | 40.0        |
# |    co2_emission                     | 0.0         |
# |    day_of_month                     | 1.0         |
# |    diffuse_solar_radiation          | 0.0         |
# |    direct_solar_radiation           | 0.0         |
# |    hour                             | 0.0         |
# |    htg_setpoint                     | 12.8        |
# |    month                            | 1.0         |
# |    outdoor_humidity                 | 43.25       |
# |    outdoor_temperature              | -9.456629   |
# |    people_occupant                  | 0.0         |
# |    total_electricity_HVAC           | 2918436.8   |
# |    wind_direction                   | 305.0       |
# |    wind_speed                       | 8.4         |
# | rollout/                            |             |
# |    exploration_rate                 | 0.05        |
# | train/                              |             |
# |    learning_rate                    | 0.0001      |
# |    loss                             | 1.88e+03    |
# |    n_updates                        | 31298       |
# -----------------------------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 3.5e+04   |
# |    ep_rew_mean      | -1.95e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 3         |
# |    fps              | 552       |
# |    time_elapsed     | 317       |
# |    total_timesteps  | 175194    |
# -----------------------------------
# -----------------------------------------------
# | action_network/                 |           |
# |    index                        | 9         |
# | action_simulation/              |           |
# |    Cooling_Setpoint_RL          | 21        |
# |    Heating_Setpoint_RL          | 21        |
# | observation/                    |           |
# |    HVAC_electricity_demand_rate | 2568.4902 |
# |    air_humidity                 | 19.359264 |
# |    air_temperature              | 14.586013 |
# |    clg_setpoint                 | 40.0      |
# |    co2_emission                 | 0.0       |
# |    day_of_month                 | 1.0       |
# |    diffuse_solar_radiation      | 0.0       |
# |    direct_solar_radiation       | 0.0       |
# |    hour                         | 0.0       |
# |    htg_setpoint                 | 12.8      |
# |    month                        | 1.0       |
# |    outdoor_humidity             | 57.75     |
# |    outdoor_temperature          | -6.085543 |
# |    people_occupant              | 0.0       |
# |    total_electricity_HVAC       | 2311641.2 |
# |    wind_direction               | 275.0     |
# |    wind_speed                   | 7.6       |
# | rollout/                        |           |
# |    exploration_rate             | 0.05      |
# | train/                          |           |
# |    learning_rate                | 0.0001    |
# |    loss                         | 2.27e+03  |
# |    n_updates                    | 31299     |
# -----------------------------------------------
# /usr/local/lib/python3.10/dist-packages/gymnasium/core.py:311: UserWarning: WARN: env.observation_variables to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.observation_variables` for environment variables or `env.get_wrapper_attr('observation_variables')` that will search the reminding wrappers.
#   logger.warn(
# /usr/local/lib/python3.10/dist-packages/gymnasium/core.py:311: UserWarning: WARN: env.action_variables to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.action_variables` for environment variables or `env.get_wrapper_attr('action_variables')` that will search the reminding wrappers.
#   logger.warn(
# /usr/local/lib/python3.10/dist-packages/gymnasium/core.py:311: UserWarning: WARN: env.flag_discrete to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.flag_discrete` for environment variables or `env.get_wrapper_attr('flag_discrete')` that will search the reminding wrappers.
#   logger.warn(

# %% [markdown]
# Now, we save the current model (model version when training has finished).

# %%
model.save(env.get_wrapper_attr('timestep_per_episode')+ '/' + experiment_name)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /workspaces/sinergym/examples/drl.ipynb Celda 25 line 1
# ----> <a href='vscode-notebook-cell://dev-container%2B2f686f6d652f616c65782f4573637269746f72696f2f73696e657267796d/workspaces/sinergym/examples/drl.ipynb#X33sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> model.save(env.get_wrapper_attr('timestep_per_episode')+ '/' + experiment_name)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# And as always, remember to close the environment.

# %%
env.close()
# Out:
# [WRAPPER LoggerWrapper] (INFO) : End of episode, recording summary (progress.csv) if logger is active
# Progress: |***************************************************************************************************| 99%
# [ENVIRONMENT] (INFO) : Environment closed. [SB3_DQN-Eplus-5zone-mixed-discrete-stochastic-v1-episodes-5_2023-08-03_13:33]

# %% [markdown]
# We have to upload all Sinergym output as *wandb* artifact. This output include all sinergym_output (and LoggerWrapper CSV files) and models generated in training and evaluation episodes.

# %%
artifact = wandb.Artifact(
        name="experiment1",
        type="training")
artifact.add_dir(
        env.get_wrapper_attr('timestep_per_episode'),
        name='training_output/')
artifact.add_dir(
    eval_env.get_wrapper_attr('timestep_per_episode'),
    name='evaluation_output/')
run.log_artifact(artifact)

# wandb has finished
run.finish()
# Out:
# wandb: Adding directory to artifact (/workspaces/sinergym/examples/Eplus-env-SB3_DQN-Eplus-5zone-mixed-discrete-stochastic-v1-episodes-5_2023-08-03_13:33-res1)... Done. 0.1s
# wandb: Adding directory to artifact (/workspaces/sinergym/examples/Eplus-env-SB3_DQN-Eplus-5zone-mixed-discrete-stochastic-v1-episodes-5_2023-08-03_13:33_EVALUATION-res1)... Done. 0.0s
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>action/Cooling_Setpoint_RL</td><td>█▃▃▃▁</td></tr><tr><td>action/Heating_Setpoint_RL</td><td>▁▅▆▆█</td></tr><tr><td>action_simulation/Cooling_Setpoint_RL</td><td>█▃▃▃▁</td></tr><tr><td>action_simulation/Heating_Setpoint_RL</td><td>▁▅▆▆█</td></tr><tr><td>episode/comfort_violation_time(%)</td><td>▁▁██▇</td></tr><tr><td>episode/cumulative_comfort_penalty</td><td>██▁▁▁</td></tr><tr><td>episode/cumulative_power</td><td>▁▁███</td></tr><tr><td>episode/cumulative_power_penalty</td><td>██▁▁▁</td></tr><tr><td>episode/cumulative_reward</td><td>██▁▁▁</td></tr><tr><td>episode/ep_length</td><td>▁▁███</td></tr><tr><td>episode/mean_comfort_penalty</td><td>██▃▃▁</td></tr><tr><td>episode/mean_power</td><td>██▁▁▆</td></tr><tr><td>episode/mean_power_penalty</td><td>▁▁██▃</td></tr><tr><td>episode/mean_reward</td><td>██▃▃▁</td></tr><tr><td>eval/comfort_penalty</td><td>█▁</td></tr><tr><td>eval/comfort_violation(%)</td><td>▁█</td></tr><tr><td>eval/mean_cumulative_reward</td><td>█▁</td></tr><tr><td>eval/mean_ep_length</td><td>▁▁</td></tr><tr><td>eval/mean_power_consumption</td><td>█▁</td></tr><tr><td>eval/mean_reward</td><td>█▁</td></tr><tr><td>eval/power_penalty</td><td>▁█</td></tr><tr><td>eval/std_cumulative_reward</td><td>▁▁</td></tr><tr><td>eval/std_reward</td><td>▁▁</td></tr><tr><td>observation/HVAC_electricity_demand_rate</td><td>█▁▄▇▇</td></tr><tr><td>observation/air_humidity</td><td>▄▆▁█▁</td></tr><tr><td>observation/air_temperature</td><td>█▅▇▃▁</td></tr><tr><td>observation/clg_setpoint</td><td>█▄▃▃▁</td></tr><tr><td>observation/co2_emission</td><td>▁▁▁▁▁</td></tr><tr><td>observation/day_of_month</td><td>█▁▅▁▅</td></tr><tr><td>observation/diffuse_solar_radiation</td><td>▂█▁█▁</td></tr><tr><td>observation/direct_solar_radiation</td><td>▂█▁█▁</td></tr><tr><td>observation/hour</td><td>█▁▅▁▅</td></tr><tr><td>observation/htg_setpoint</td><td>▁▅▅▆█</td></tr><tr><td>observation/month</td><td>█▁▄▁▄</td></tr><tr><td>observation/outdoor_humidity</td><td>▂█▁█▁</td></tr><tr><td>observation/outdoor_temperature</td><td>█▇▁█▁</td></tr><tr><td>observation/people_occupant</td><td>▂█▁█▁</td></tr><tr><td>observation/total_electricity_HVAC</td><td>█▁▄▆▇</td></tr><tr><td>observation/wind_direction</td><td>▇▁█▁█</td></tr><tr><td>observation/wind_speed</td><td>▇▁█▁█</td></tr><tr><td>rollout/ep_len_mean</td><td>▁▁▁</td></tr><tr><td>rollout/ep_rew_mean</td><td>█▃▁</td></tr><tr><td>rollout/exploration_rate</td><td>▁▁▁▁▁</td></tr><tr><td>time/episodes</td><td>▁▅█</td></tr><tr><td>time/fps</td><td>█▂▁</td></tr><tr><td>time/time_elapsed</td><td>▁▄█</td></tr><tr><td>time/total_timesteps</td><td>▁▃▅▆█</td></tr><tr><td>train/learning_rate</td><td>▁▁▁▁</td></tr><tr><td>train/loss</td><td>▄▁▅█</td></tr><tr><td>train/n_updates</td><td>▁▃▆█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>action/Cooling_Setpoint_RL</td><td>25.16472</td></tr><tr><td>action/Heating_Setpoint_RL</td><td>19.41009</td></tr><tr><td>action_simulation/Cooling_Setpoint_RL</td><td>25.16472</td></tr><tr><td>action_simulation/Heating_Setpoint_RL</td><td>19.41009</td></tr><tr><td>episode/comfort_violation_time(%)</td><td>51.4534</td></tr><tr><td>episode/cumulative_comfort_penalty</td><td>-70523.31224</td></tr><tr><td>episode/cumulative_power</td><td>72096653.57696</td></tr><tr><td>episode/cumulative_power_penalty</td><td>-7209.66536</td></tr><tr><td>episode/cumulative_reward</td><td>-38866.48828</td></tr><tr><td>episode/ep_length</td><td>70077</td></tr><tr><td>episode/mean_comfort_penalty</td><td>-1.00637</td></tr><tr><td>episode/mean_power</td><td>1028.82049</td></tr><tr><td>episode/mean_power_penalty</td><td>-0.10288</td></tr><tr><td>episode/mean_reward</td><td>-0.55463</td></tr><tr><td>eval/comfort_penalty</td><td>-58007.70886</td></tr><tr><td>eval/comfort_violation(%)</td><td>67.52854</td></tr><tr><td>eval/mean_cumulative_reward</td><td>-30746.62654 ...
#  View run <strong style="color:#cdcd00">SB3_DQN-Eplus-5zone-mixed-discrete-stochastic-v1-episodes-5_2023-08-03_13:33_ud7kza7m</strong> at: <a href='https://wandb.ai/alex_ugr/sinergym/runs/bvwtjd74' target="_blank">https://wandb.ai/alex_ugr/sinergym/runs/bvwtjd74</a><br/>Synced 5 W&B file(s), 0 media file(s), 151 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230803_133346-bvwtjd74/logs</code>

# %% [markdown]
# We have all the experiments results in our local computer, but we can see the execution in *wandb* too:
#
#
# - If we check our projects, we can see the execution allocated:
#
# ![wandb_projects1](https://github.com/ugr-sail/sinergym/blob/main/images/wandb_projects1.png?raw=true)
#
#
# - Hyperparameters tracked in the training experiment:
#
# ![wandb_training_hyperparameters](https://github.com/ugr-sail/sinergym/blob/main/images/wandb_training_hyperparameters.png?raw=true)
#
#
#
# - Artifacts registered (if evaluation is enabled, best model is registered too):
#
# ![wandb_training_artifact](https://github.com/ugr-sail/sinergym/blob/main/images/wandb_training_artifact.png?raw=true)
#
#
#
# - Visualization of metrics in real time:
#
# ![wandb_training_charts](https://github.com/ugr-sail/sinergym/blob/main/images/wandb_training_charts.png?raw=true)

# %% [markdown]
# ## Loading a model

# %% [markdown]
# We are going to rely on the script available in the repository root called `load_agent.py`. This script applies all the possibilities that Sinergym has to work with deep reinforcement learning models loaded and set parameters to everything, so that we can define the load options from the execution of the script easily by a JSON file.
#
# For more information about how run `load_agent.py`, please, see [Load a trained model](https://ugr-sail.github.io/sinergym/compilation/main/pages/deep-reinforcement-learning.html#load-a-trained-model).

# %% [markdown]
# First, we define the Sinergym environment ID where we want to check the loaded agent and the name of the evaluation experiment.

# %%
# Environment ID
environment = "Eplus-5zone-mixed-discrete-stochastic-v1"
# Episodes
episodes=5
# Evaluation name
evaluation_date = datetime.today().strftime('%Y-%m-%d_%H:%M')
evaluation_name = 'SB3_DQN-EVAL-' + environment + \
    '-episodes-' + str(episodes)
evaluation_name += '_' + evaluation_date

# %% [markdown]
# We can also use *wandb* here. We can allocate this evaluation of a loaded model in other project in order to not merge experiments.

# %%
# Create wandb.config object in order to log all experiment params
experiment_params = {
    'sinergym-version': sinergym.__version__,
    'python-version': sys.version
}
experiment_params.update({'environment':environment,
                          'episodes':episodes,
                          'algorithm':'SB3_DQN'})

# Get wandb init params (you have to specify your own project and entity)
wandb_params = {"project": 'sinergym_evaluations',
                "entity": 'alex_ugr'}
# Init wandb entry
run = wandb.init(
    name=experiment_name + '_' + wandb.util.generate_id(),
    config=experiment_params,
    ** wandb_params
)
# Out:
# wandb version 0.15.8 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.15.5
# Run data is saved locally in <code>/workspaces/sinergym/examples/wandb/run-20230803_133654-empzk2on</code>
# Syncing run <strong><a href='https://wandb.ai/alex_ugr/sinergym_evaluations/runs/empzk2on' target="_blank">SB3_DQN-Eplus-5zone-mixed-discrete-stochastic-v1-episodes-5_2023-08-03_13:33_hu200t1q</a></strong> to <a href='https://wandb.ai/alex_ugr/sinergym_evaluations' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/alex_ugr/sinergym_evaluations' target="_blank">https://wandb.ai/alex_ugr/sinergym_evaluations</a>
#  View run at <a href='https://wandb.ai/alex_ugr/sinergym_evaluations/runs/empzk2on' target="_blank">https://wandb.ai/alex_ugr/sinergym_evaluations/runs/empzk2on</a>

# %% [markdown]
# We make the gymnasium environment and wrap with LoggerWrapper. We can use the evaluation experiment name to rename the environment.

# %%
env=gym.make(environment, env_name=evaluation_name)
env=LoggerWrapper(env)
# Out:
# #==============================================================================================#
# [ENVIRONMENT] (INFO) : Creating Gymnasium environment... [SB3_DQN-EVAL-Eplus-5zone-mixed-discrete-stochastic-v1-episodes-5_2023-08-03_13:36]
# #==============================================================================================#
# [MODELING] (INFO) : Experiment working directory created [/workspaces/sinergym/examples/Eplus-env-SB3_DQN-EVAL-Eplus-5zone-mixed-discrete-stochastic-v1-episodes-5_2023-08-03_13:36-res1]
# [MODELING] (INFO) : runperiod established: {'start_day': 1, 'start_month': 1, 'start_year': 1991, 'end_day': 31, 'end_month': 12, 'end_year': 1991, 'start_weekday': 1, 'n_steps_per_hour': 4}
# [MODELING] (INFO) : Episode length (seconds): 31536000.0
# [MODELING] (INFO) : timestep size (seconds): 900.0
# [MODELING] (INFO) : timesteps per episode: 35040
# [MODELING] (INFO) : Model Config is correct.
# [ENVIRONMENT] (INFO) : Environment SB3_DQN-EVAL-Eplus-5zone-mixed-discrete-stochastic-v1-episodes-5_2023-08-03_13:36 created successfully.
# [WRAPPER LoggerWrapper] (INFO) : Wrapper initialized.

# %% [markdown]
# We load the Stable Baselines 3 DQN model using the model allocated in our local computer, although we can use a remote model allocated in *wandb* from other training experiment.

# %%
# get wandb artifact path (to load model)
load_artifact_entity = 'alex_ugr'
load_artifact_project = 'sinergym'
load_artifact_name = 'experiment1'
load_artifact_tag = 'latest'
load_artifact_model_path = 'evaluation_output/best_model/model.zip'
wandb_path = load_artifact_entity + '/' + load_artifact_project + \
    '/' + load_artifact_name + ':' + load_artifact_tag
# Download artifact
artifact = run.use_artifact(wandb_path)
artifact.get_path(load_artifact_model_path).download('.')
# Set model path to local wandb file downloaded
model_path = './' + load_artifact_model_path
model = DQN.load(model_path)

# %% [markdown]
# As we can see, The *wandb* model we want to load can come from an artifact of an different entity or project from the one we are using to register the evaluation of the loaded model, as long as it is accessible.
# The next step is use the model to predict actions and interact with the environment in order to collect data to evaluate the model.

# %%
for i in range(episodes):
    obs, info = env.reset()
    rewards = []
    terminated = False
    current_month = 0
    while not terminated:
        a, _ = model.predict(obs)
        obs, reward, terminated, truncated, info = env.step(a)
        rewards.append(reward)
        if info['month'] != current_month:
            current_month = info['month']
            print(info['month'], sum(rewards))
    print(
        'Episode ',
        i,
        'Mean reward: ',
        np.mean(rewards),
        'Cumulative reward: ',
        sum(rewards))
env.close()
# Out:
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode... [SB3_DQN-EVAL-Eplus-5zone-mixed-discrete-stochastic-v1-episodes-5_2023-08-03_13:36] [Episode 1]
# #----------------------------------------------------------------------------------------------#
# [MODELING] (INFO) : Episode directory created [/workspaces/sinergym/examples/Eplus-env-SB3_DQN-EVAL-Eplus-5zone-mixed-discrete-stochastic-v1-episodes-5_2023-08-03_13:36-res1/Eplus-env-sub_run1]
# [MODELING] (INFO) : Weather file USA_NY_New.York-J.F.Kennedy.Intl.AP.744860_TMY3.epw used.
# [MODELING] (INFO) : Updated building model with whole Output:Variable available names
# [MODELING] (INFO) : Updated building model with whole Output:Meter available names
# [MODELING] (INFO) : Adapting weather to building model. [USA_NY_New.York-J.F.Kennedy.Intl.AP.744860_TMY3.epw]
# [ENVIRONMENT] (INFO) : Saving episode output path... [/workspaces/sinergym/examples/Eplus-env-SB3_DQN-EVAL-Eplus-5zone-mixed-discrete-stochastic-v1-episodes-5_2023-08-03_13:36-res1/Eplus-env-sub_run1/output]
# [SIMULATOR] (INFO) : Running EnergyPlus with args: ['-w', '/workspaces/sinergym/examples/Eplus-env-SB3_DQN-EVAL-Eplus-5zone-mixed-discrete-stochastic-v1-episodes-5_2023-08-03_13:36-res1/Eplus-env-sub_run1/USA_NY_New.York-J.F.Kennedy.Intl.AP.744860_TMY3_Random_1.0_0.0_0.001.epw', '-d', '/workspaces/sinergym/examples/Eplus-env-SB3_DQN-EVAL-Eplus-5zone-mixed-discrete-stochastic-v1-episodes-5_2023-08-03_13:36-res1/Eplus-env-sub_run1/output', '/workspaces/sinergym/examples/Eplus-env-SB3_DQN-EVAL-Eplus-5zone-mixed-discrete-stochastic-v1-episodes-5_2023-08-03_13:36-res1/Eplus-env-sub_run1/5ZoneAutoDXVAV.epJSON']
# [ENVIRONMENT] (INFO) : Episode 1 started.
# /usr/local/lib/python3.10/dist-packages/opyplus/weather_data/weather_data.py:493: FutureWarning: the 'line_terminator'' keyword is deprecated, use 'lineterminator' instead.
#   epw_content = self._headers_to_epw(use_datetimes=use_datetimes) + df.to_csv(
# [SIMULATOR] (INFO) : Handles initialized.
# [SIMULATOR] (INFO) : Handles are ready.
# [SIMULATOR] (INFO) : System is ready.
# [WRAPPER LoggerWrapper] (INFO) : Creating monitor.csv for current episode (episode 1) if logger is active
# 1 -2.923534945260318
# 2 -545.9675551477944------------------------------------------------------------------------------------------| 9%
# 3 -1053.746855897233*******-----------------------------------------------------------------------------------| 16%
# 4 -1538.6951964648028***************--------------------------------------------------------------------------| 25%
# 5 -3263.7965536177353***********************------------------------------------------------------------------| 33%
# 6 -4591.484569761892********************************----------------------------------------------------------| 41%
# 7 -6091.750547652644*****************************************-------------------------------------------------| 50%
# 8 -7675.242465461302************************************************------------------------------------------| 58%
# 9 -9644.855276527725*********************************************************---------------------------------| 66%
# 10 -11367.84622925184*****************************************************************------------------------| 75%
# 11 -13645.675820447477************************************************************************----------------| 83%
# 12 -14107.348329344835********************************************************************************--------| 91%
# Progress: |***************************************************************************************************| 99%
# Episode  0 Mean reward:  -0.41950243794317843 Cumulative reward:  -14699.365425527394
# [WRAPPER LoggerWrapper] (INFO) : End of episode detected, recording summary (progress.csv) if logger is active
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode... [SB3_DQN-EVAL-Eplus-5zone-mixed-discrete-stochastic-v1-episodes-5_2023-08-03_13:36] [Episode 2]
# #----------------------------------------------------------------------------------------------#
# [MODELING] (INFO) : Episode directory created [/workspaces/sinergym/examples/Eplus-env-SB3_DQN-EVAL-Eplus-5zone-mixed-discrete-stochastic-v1-episodes-5_2023-08-03_13:36-res1/Eplus-env-sub_run2]
# [MODELING] (INFO) : Weather file USA_NY_New.York-J.F.Kennedy.Intl.AP.744860_TMY3.epw used.
# [MODELING] (INFO) : Updated building model with whole Output:Variable available names
# [MODELING] (INFO) : Updated building model with whole Output:Meter available names
# [MODELING] (INFO) : Adapting weather to building model. [USA_NY_New.York-J.F.Kennedy.Intl.AP.744860_TMY3.epw]
# [ENVIRONMENT] (INFO) : Saving episode output path... [/workspaces/sinergym/examples/Eplus-env-SB3_DQN-EVAL-Eplus-5zone-mixed-discrete-stochastic-v1-episodes-5_2023-08-03_13:36-res1/Eplus-env-sub_run2/output]
# [SIMULATOR] (INFO) : Running EnergyPlus with args: ['-w', '/workspaces/sinergym/examples/Eplus-env-SB3_DQN-EVAL-Eplus-5zone-mixed-discrete-stochastic-v1-episodes-5_2023-08-03_13:36-res1/Eplus-env-sub_run2/USA_NY_New.York-J.F.Kennedy.Intl.AP.744860_TMY3_Random_1.0_0.0_0.001.epw', '-d', '/workspaces/sinergym/examples/Eplus-env-SB3_DQN-EVAL-Eplus-5zone-mixed-discrete-stochastic-v1-episodes-5_2023-08-03_13:36-res1/Eplus-env-sub_run2/output', '/workspaces/sinergym/examples/Eplus-env-SB3_DQN-EVAL-Eplus-5zone-mixed-discrete-stochastic-v1-episodes-5_2023-08-03_13:36-res1/Eplus-env-sub_run2/5ZoneAutoDXVAV.epJSON']
# [ENVIRONMENT] (INFO) : Episode 2 started.
# /usr/local/lib/python3.10/dist-packages/opyplus/weather_data/weather_data.py:493: FutureWarning: the 'line_terminator'' keyword is deprecated, use 'lineterminator' instead.
#   epw_content = self._headers_to_epw(use_datetimes=use_datetimes) + df.to_csv(
# [SIMULATOR] (INFO) : Handles are ready.
# [SIMULATOR] (INFO) : System is ready.
# [WRAPPER LoggerWrapper] (INFO) : Creating monitor.csv for current episode (episode 2) if logger is active
# 1 -2.925224776062733
# 2 -548.262830920861*------------------------------------------------------------------------------------------| 9%
# 3 -1058.5062791381658******-----------------------------------------------------------------------------------| 16%
# 4 -1575.8530805786577***************--------------------------------------------------------------------------| 25%
# 5 -3306.2620501266692***********************------------------------------------------------------------------| 33%
# 6 -4704.056431691431********************************----------------------------------------------------------| 41%
# 7 -6217.987133024803*****************************************-------------------------------------------------| 50%
# 8 -7784.173975985413************************************************------------------------------------------| 58%
# 9 -9686.581886177888*********************************************************---------------------------------| 66%
# 10 -11367.316001700072****************************************************************------------------------| 75%
# 11 -13621.745435351058************************************************************************----------------| 83%
# 12 -14094.360668740097********************************************************************************--------| 91%
# Progress: |***************************************************************************************************| 99%
# Episode  1 Mean reward:  -0.41894717522846364 Cumulative reward:  -14679.90902000385
# [WRAPPER LoggerWrapper] (INFO) : End of episode detected, recording summary (progress.csv) if logger is active
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode... [SB3_DQN-EVAL-Eplus-5zone-mixed-discrete-stochastic-v1-episodes-5_2023-08-03_13:36] [Episode 3]
# #----------------------------------------------------------------------------------------------#
# [MODELING] (INFO) : Episode directory created [/workspaces/sinergym/examples/Eplus-env-SB3_DQN-EVAL-Eplus-5zone-mixed-discrete-stochastic-v1-episodes-5_2023-08-03_13:36-res1/Eplus-env-sub_run3]
# [MODELING] (INFO) : Weather file USA_NY_New.York-J.F.Kennedy.Intl.AP.744860_TMY3.epw used.
# [MODELING] (INFO) : Updated building model with whole Output:Variable available names
# [MODELING] (INFO) : Updated building model with whole Output:Meter available names
# [MODELING] (INFO) : Adapting weather to building model. [USA_NY_New.York-J.F.Kennedy.Intl.AP.744860_TMY3.epw]
# [ENVIRONMENT] (INFO) : Saving episode output path... [/workspaces/sinergym/examples/Eplus-env-SB3_DQN-EVAL-Eplus-5zone-mixed-discrete-stochastic-v1-episodes-5_2023-08-03_13:36-res1/Eplus-env-sub_run3/output]
# [SIMULATOR] (INFO) : Running EnergyPlus with args: ['-w', '/workspaces/sinergym/examples/Eplus-env-SB3_DQN-EVAL-Eplus-5zone-mixed-discrete-stochastic-v1-episodes-5_2023-08-03_13:36-res1/Eplus-env-sub_run3/USA_NY_New.York-J.F.Kennedy.Intl.AP.744860_TMY3_Random_1.0_0.0_0.001.epw', '-d', '/workspaces/sinergym/examples/Eplus-env-SB3_DQN-EVAL-Eplus-5zone-mixed-discrete-stochastic-v1-episodes-5_2023-08-03_13:36-res1/Eplus-env-sub_run3/output', '/workspaces/sinergym/examples/Eplus-env-SB3_DQN-EVAL-Eplus-5zone-mixed-discrete-stochastic-v1-episodes-5_2023-08-03_13:36-res1/Eplus-env-sub_run3/5ZoneAutoDXVAV.epJSON']
# [ENVIRONMENT] (INFO) : Episode 3 started.
# /usr/local/lib/python3.10/dist-packages/opyplus/weather_data/weather_data.py:493: FutureWarning: the 'line_terminator'' keyword is deprecated, use 'lineterminator' instead.
#   epw_content = self._headers_to_epw(use_datetimes=use_datetimes) + df.to_csv(
# [SIMULATOR] (INFO) : Handles are ready.
# [SIMULATOR] (INFO) : System is ready.
# [WRAPPER LoggerWrapper] (INFO) : Creating monitor.csv for current episode (episode 3) if logger is active
# 1 -2.7919005989982817
# 2 -553.9519593861705------------------------------------------------------------------------------------------| 9%
# 3 -1066.098112779678*******-----------------------------------------------------------------------------------| 16%
# 4 -1560.9201826366045***************--------------------------------------------------------------------------| 25%
# 5 -3286.9211366941868***********************------------------------------------------------------------------| 33%
# 6 -4660.212425594923********************************----------------------------------------------------------| 41%
# 7 -6147.960543074123*****************************************-------------------------------------------------| 50%
# 8 -7743.014540574517************************************************------------------------------------------| 58%
# 9 -9648.436575176998*********************************************************---------------------------------| 66%
# 10 -11327.20309820599*****************************************************************------------------------| 75%
# 11 -13603.34240336748*************************************************************************----------------| 83%
# 12 -14089.751097336599********************************************************************************--------| 91%
# Progress: |***************************************************************************************************| 99%
# Episode  2 Mean reward:  -0.41898931985658516 Cumulative reward:  -14681.38576777339
# [WRAPPER LoggerWrapper] (INFO) : End of episode detected, recording summary (progress.csv) if logger is active
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode... [SB3_DQN-EVAL-Eplus-5zone-mixed-discrete-stochastic-v1-episodes-5_2023-08-03_13:36] [Episode 4]
# #----------------------------------------------------------------------------------------------#
# [MODELING] (INFO) : Episode directory created [/workspaces/sinergym/examples/Eplus-env-SB3_DQN-EVAL-Eplus-5zone-mixed-discrete-stochastic-v1-episodes-5_2023-08-03_13:36-res1/Eplus-env-sub_run4]
# [MODELING] (INFO) : Weather file USA_NY_New.York-J.F.Kennedy.Intl.AP.744860_TMY3.epw used.
# [MODELING] (INFO) : Updated building model with whole Output:Variable available names
# [MODELING] (INFO) : Updated building model with whole Output:Meter available names
# [MODELING] (INFO) : Adapting weather to building model. [USA_NY_New.York-J.F.Kennedy.Intl.AP.744860_TMY3.epw]
# [ENVIRONMENT] (INFO) : Saving episode output path... [/workspaces/sinergym/examples/Eplus-env-SB3_DQN-EVAL-Eplus-5zone-mixed-discrete-stochastic-v1-episodes-5_2023-08-03_13:36-res1/Eplus-env-sub_run4/output]
# [SIMULATOR] (INFO) : Running EnergyPlus with args: ['-w', '/workspaces/sinergym/examples/Eplus-env-SB3_DQN-EVAL-Eplus-5zone-mixed-discrete-stochastic-v1-episodes-5_2023-08-03_13:36-res1/Eplus-env-sub_run4/USA_NY_New.York-J.F.Kennedy.Intl.AP.744860_TMY3_Random_1.0_0.0_0.001.epw', '-d', '/workspaces/sinergym/examples/Eplus-env-SB3_DQN-EVAL-Eplus-5zone-mixed-discrete-stochastic-v1-episodes-5_2023-08-03_13:36-res1/Eplus-env-sub_run4/output', '/workspaces/sinergym/examples/Eplus-env-SB3_DQN-EVAL-Eplus-5zone-mixed-discrete-stochastic-v1-episodes-5_2023-08-03_13:36-res1/Eplus-env-sub_run4/5ZoneAutoDXVAV.epJSON']
# [ENVIRONMENT] (INFO) : Episode 4 started.
# /usr/local/lib/python3.10/dist-packages/opyplus/weather_data/weather_data.py:493: FutureWarning: the 'line_terminator'' keyword is deprecated, use 'lineterminator' instead.
#   epw_content = self._headers_to_epw(use_datetimes=use_datetimes) + df.to_csv(
# [SIMULATOR] (INFO) : Handles are ready.
# [SIMULATOR] (INFO) : System is ready.
# [WRAPPER LoggerWrapper] (INFO) : Creating monitor.csv for current episode (episode 4) if logger is active
# 1 -2.78824095830562
# 2 -557.1094170940659------------------------------------------------------------------------------------------| 9%
# 3 -1067.8894261383139******-----------------------------------------------------------------------------------| 16%
# 4 -1532.3300955107861***************--------------------------------------------------------------------------| 25%
# 5 -3273.1273063036533***********************------------------------------------------------------------------| 33%
# 6 -4682.13989435092*********************************----------------------------------------------------------| 41%
# 7 -6188.620556285447*****************************************-------------------------------------------------| 50%
# 8 -7778.9295888679**************************************************------------------------------------------| 58%
# 9 -9733.548610368716*********************************************************---------------------------------| 66%
# 10 -11396.738321102088****************************************************************------------------------| 75%
# 11 -13636.896527096984************************************************************************----------------| 83%
# 12 -14108.25626219889*********************************************************************************--------| 91%
# Progress: |***************************************************************************************************| 99%
# Episode  3 Mean reward:  -0.4194283789134086 Cumulative reward:  -14696.770397124146
# [WRAPPER LoggerWrapper] (INFO) : End of episode detected, recording summary (progress.csv) if logger is active
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode... [SB3_DQN-EVAL-Eplus-5zone-mixed-discrete-stochastic-v1-episodes-5_2023-08-03_13:36] [Episode 5]
# #----------------------------------------------------------------------------------------------#
# [MODELING] (INFO) : Episode directory created [/workspaces/sinergym/examples/Eplus-env-SB3_DQN-EVAL-Eplus-5zone-mixed-discrete-stochastic-v1-episodes-5_2023-08-03_13:36-res1/Eplus-env-sub_run5]
# [MODELING] (INFO) : Weather file USA_NY_New.York-J.F.Kennedy.Intl.AP.744860_TMY3.epw used.
# [MODELING] (INFO) : Updated building model with whole Output:Variable available names
# [MODELING] (INFO) : Updated building model with whole Output:Meter available names
# [MODELING] (INFO) : Adapting weather to building model. [USA_NY_New.York-J.F.Kennedy.Intl.AP.744860_TMY3.epw]
# [ENVIRONMENT] (INFO) : Saving episode output path... [/workspaces/sinergym/examples/Eplus-env-SB3_DQN-EVAL-Eplus-5zone-mixed-discrete-stochastic-v1-episodes-5_2023-08-03_13:36-res1/Eplus-env-sub_run5/output]
# [SIMULATOR] (INFO) : Running EnergyPlus with args: ['-w', '/workspaces/sinergym/examples/Eplus-env-SB3_DQN-EVAL-Eplus-5zone-mixed-discrete-stochastic-v1-episodes-5_2023-08-03_13:36-res1/Eplus-env-sub_run5/USA_NY_New.York-J.F.Kennedy.Intl.AP.744860_TMY3_Random_1.0_0.0_0.001.epw', '-d', '/workspaces/sinergym/examples/Eplus-env-SB3_DQN-EVAL-Eplus-5zone-mixed-discrete-stochastic-v1-episodes-5_2023-08-03_13:36-res1/Eplus-env-sub_run5/output', '/workspaces/sinergym/examples/Eplus-env-SB3_DQN-EVAL-Eplus-5zone-mixed-discrete-stochastic-v1-episodes-5_2023-08-03_13:36-res1/Eplus-env-sub_run5/5ZoneAutoDXVAV.epJSON']
# [ENVIRONMENT] (INFO) : Episode 5 started.
# /usr/local/lib/python3.10/dist-packages/opyplus/weather_data/weather_data.py:493: FutureWarning: the 'line_terminator'' keyword is deprecated, use 'lineterminator' instead.
#   epw_content = self._headers_to_epw(use_datetimes=use_datetimes) + df.to_csv(
# [SIMULATOR] (INFO) : Handles are ready.
# [SIMULATOR] (INFO) : System is ready.
# [WRAPPER LoggerWrapper] (INFO) : Creating monitor.csv for current episode (episode 5) if logger is active
# 1 -2.84397461513269
# 2 -552.3501239139867------------------------------------------------------------------------------------------| 9%
# 3 -1063.132403854795*******-----------------------------------------------------------------------------------| 16%
# 4 -1538.677885306011****************--------------------------------------------------------------------------| 25%
# 5 -3241.4892282191527***********************------------------------------------------------------------------| 33%
# 6 -4578.837169499202********************************----------------------------------------------------------| 41%
# 7 -6014.590520477295*****************************************-------------------------------------------------| 50%
# 8 -7598.554487446062************************************************------------------------------------------| 58%
# 9 -9556.89837322453**********************************************************---------------------------------| 66%
# 10 -11216.899244286305****************************************************************------------------------| 75%
# 11 -13359.969324879577************************************************************************----------------| 83%
# 12 -13833.20644698031*********************************************************************************--------| 91%
# Progress: |***************************************************************************************************| 99%
# Episode  4 Mean reward:  -0.41174758683638085 Cumulative reward:  -14427.635442745244
# [WRAPPER LoggerWrapper] (INFO) : End of episode, recording summary (progress.csv) if logger is active
# [ENVIRONMENT] (INFO) : Environment closed. [SB3_DQN-EVAL-Eplus-5zone-mixed-discrete-stochastic-v1-episodes-5_2023-08-03_13:36]

# %% [markdown]
# Finally, we register the evaluation data in wandb as an artifact to save it.

# %%
artifact = wandb.Artifact(
    name="evaluation1",
    type="evaluating")
artifact.add_dir(
    env.experiment_path,
    name='evaluation_output/')

run.log_artifact(artifact)

# wandb has finished
run.finish()
# Out:
# wandb: Adding directory to artifact (/workspaces/sinergym/examples/Eplus-env-SB3_DQN-EVAL-Eplus-5zone-mixed-discrete-stochastic-v1-episodes-5_2023-08-03_13:36-res1)... Done. 0.1s
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
#  View run <strong style="color:#cdcd00">SB3_DQN-Eplus-5zone-mixed-discrete-stochastic-v1-episodes-5_2023-08-03_13:33_hu200t1q</strong> at: <a href='https://wandb.ai/alex_ugr/sinergym_evaluations/runs/empzk2on' target="_blank">https://wandb.ai/alex_ugr/sinergym_evaluations/runs/empzk2on</a><br/>Synced 5 W&B file(s), 0 media file(s), 92 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230803_133654-empzk2on/logs</code>

# %% [markdown]
# We have the loaded model results in our local computer, but we can see the execution in *wandb* too:
#
# - If we check the wandb project list, we can see that sinergym_evaluations project has a new run:
#
# ![wandb_project2](https://github.com/ugr-sail/sinergym/blob/main/images/wandb_project2.png?raw=true)
#
#
# - Hyperparameters tracked in the evaluation experiment and we can see the previous training artifact used to load the model:
#
# ![wandb_evaluating_hyperparameters](https://github.com/ugr-sail/sinergym/blob/main/images/wandb_evaluating_hyperparameters.png?raw=true)
#
#
#
# - Artifact registered with Sinergym Output (and CSV files generated with the Logger Wrapper):
#
# ![wandb_evaluating_artifact](https://github.com/ugr-sail/sinergym/blob/main/images/wandb_evaluating_artifact.png?raw=true)
